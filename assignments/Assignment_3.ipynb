# %% [markdown]
# # DS 3001: Foundations of Machine Learning
# ## Assignment 3: Linear Regression & Cross Validation
# ## (100 Possible Points)
#
# ### **Your Name**: Last, First
#
# ### **Your Computing ID:**
#
# ### **Sign Honor Pledge Here:**
#
# On my honor as a student, I have neither given nor received unauthorized aid on this assignment.
#
# ### **Assignment Description**
#
# The questions for the third assignment of the semester, `Assignment 3`, are found below. The questions are split between the topics we discussed in the Linear Regression and Cross Validation notebooks. These questions give you the chance to combine all that we've learned into tasks that you could run into as a data scientist.
#
# For help with formatting your markdown responses in text cells, reference this [markdown style cheat sheet](https://www.markdownguide.org/cheat-sheet/).
#
# **AI Use:** For Assignment 3, you may use autofill code suggestions that Google Colab provides to you in the code blocks. You should not assume that the suggestions are always correct. Make sure that you think critically about whether the suggestions are correct or not and if they make sense with what you are trying to achieve. You may NOT use AI for the written responses in the markdown cells. I want to know what you are thinking about for your justifications, not what an LLM produces. If you have any need for clarification on this policy, please reach out to me earlier than later.
#
# **Submission Instructions:** For a complete submission, please upload your completed Assignment 3 notebook (.ipynb) on Canvas.

# %% [markdown]
# #### Setting up your directory

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os # For changing directory

# To mount your google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
path_to_DS_3001_folder = '/content/drive/MyDrive/DS-3001/assignments/'
# path_to_DS_3001_folder = ''

# Update the path to your folder for the class
# Where you stored the data from the previous noteboook
os.chdir(path_to_DS_3001_folder)

# %% [markdown]
# ## **Question 1 (10 Points Total):** Please answer the following questions in your own words. Your answers should be between 1-4 sentences.

# %% [markdown]
# **Q1.1 (1 Point)**: What makes a linear regression model "linear"? "Linear" in what?
#
# **Answer Here:**

# %% [markdown]
# **Q1.2 (2 Points)**: How do you interpret the coefficient for a dummy/one-hot-encoded variable? (Hint: how do you handle the intercept of the model?)
#
# **Answer Here:**

# %% [markdown]
# **Q1.3 (1 Point)**: What are signs that your linear model is over-fitting?
#
# **Answer Here:**

# %% [markdown]
# **Q1.4 (2 Points)**: What are two ways to incorporate nonlinear relationships between your target/outcome variable
# $y$ and your features/independent variables $x$?
#
# **Answer Here:**

# %% [markdown]
# **Q1.5 (2 Points)**: What is the interpretation of the slope coefficient in a linear regression?
#
# **Answer Here:**

# %% [markdown]
# **Q1.6 (2 Points)**: Compare and contrast the train/test split and
# k-fold cross validation. What are the advantages of using cross validation?
#
# **Answer Here:**

# %% [markdown]
# ## **Question 2 (30 Points Total):**
#
# Load `./data/nyc-airbnb-clean.csv`. The data include
#
# - `Price` per night
# - `Review Scores Rating`: The average rating for the property
# - `Neighbourhood `: The borough of NYC. Note the space, or rename the variable.
# - `Property Type`: The kind of dwelling
# - `Room Type`: The kind of space being rented
#
# **Q2.1 (2 Points)**:
#   1. Compute the average **price** and **review scores** by `Neighbourhood `.

# %%
# Answer Here

# %% [markdown]
# 2. Which borough is the most expensive on average? Report the borough and the average price.
#
# **Answer Here**:

# %% [markdown]
# 3. Which borough has the highest rating on average? Report the borough and the average rating.
#
# **Answer Here**:

# %% [markdown]
#   4. Create 2 kernel density plots: one for price and another for the log transformed price. Group both plots by `Neighbourhood `.

# %%
# Answer Here

# %% [markdown]
# 5. Interpret the results from the price KDE plots grouped by `Neighbourhood `. What are your main takeways? Hint: Think if there are differences in the distributions and note whether they could help in modeling price.
#
# **Answer Here:**

# %% [markdown]
# 6. Create a kernel density plot for review score rating grouped by `Neighbourhood `.

# %%
# Answer Here

# %% [markdown]
# 7. Interpret the results from the review rating KDE plot grouped by `Neighbourhood `. What are your main takeways? Hint: Think if there are differences in the distributions and note whether they could help in modeling price.
#
# **Answer Here:**

# %% [markdown]
# **Q2.2 (4 Points)**:
#
# 1. Fit a linear regression model with `price` as the target variable using `Neighbourhood ` as the input feature. Create the appropriate dummy/one-hot-encoded variables for `Neighbourhood `. Fit the regression model without an intercept and use all of the data. (Hint: Look at the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) for sklearn's linear regression model).

# %%
# Answer Here

# %% [markdown]
# 2. Compare the coefficients in the regression model to the table you generated in **Q2.1**. What pattern do you see? What are the coefficients in a regression of a continuous variable (target) on one categorical variable (input feature)?

# %%
# Answer Here

# %% [markdown]
# **Interpret Coefficients Here:**

# %% [markdown]
# **Q2.3 (4 Points)**:
#
# 1. Repeat **Q2.2**, but this time **fit an intercept in the linear model**. Once you've fit the model, print the estimated intercept and coefficients of the model.

# %%
# Answer Here

# %% [markdown]
# 2. How did you have to handle the creation of the dummy variables differently when you include an intercept term? What does the intercept represent in this case? Be specific to the data set.

# %% [markdown]
# **Answer Here:**

# %% [markdown]
# 3. Now interpret the coefficients of the model. What do they represent? How can you go from these new coefficients to the the coefficients you fit in **Q2.2**?
#
# **Answer Here:**

# %% [markdown]
# **Q2.4 (4 Points)**:
#
# 1. Split the data 80/20 into a training and a test set. Use a seed of `100` for reproducbility. Fit a linear regression model with `Price` as the target variables and `Review Scores Rating` and `Neighbourhood ` as the input features. Compute the root mean squared error (RMSE) on the test data. Print the coefficients of your fitted model.

# %%
# Answer Here

# %% [markdown]
# 2. What is the value of the RMSE on the test set? What is the coefficient for `Review Scores Rating`? How can you interpret this coefficient? Be specific to the data set.
#
# **Answer Here:**

# %% [markdown]
# 3. What is the most expensive kind (rating and neighborhood) of property you can rent according to your model? What would the predicted price be? (Hint: Use the coefficeints of your model)
#
# **Answer Here:**

# %%
# Answer here

# %% [markdown]
# **Q2.5 (4 Points):** In the previous example we looked at the performance of the model given one train/test split with a specific random seed. To get an understanding of the performance with different train/test splits, perform K-Fold cross validation on the model. Use `K=10` (this is called 10-Fold Cross Validation), shuffle the data (`shuffle = True`), and `random_state = 3001` Save the RMSE for each Fold. Plot the distribution of RMSE across folds as a box plot and report the mean, median, and standard deviation of the RMSE.

# %%
# Answer Here

# %% [markdown]
# **Q2.6 (4 Points):**
#
# 1. Repeat the same process as in **Q2.4** but this time, fit a regression model on `Price` using `Review Scores Rating`, `Neighbourhood `, and `Room Type` as the input features. Use a single 80/20 train/test split with a random seed of 100. Compute the root mean squared error (RMSE) on the test data. Print the coefficients of your fitted model.

# %%
# Answer Here

# %% [markdown]
# 2. What is the RMSE on the test set? What is the coefficient on `Review Scores Rating`? What is the most expensive kind of property you can rent according to this new model?
#
# **Answer Here:**

# %% [markdown]
# 3. Based on the RMSE from just the single train/test split of both models, which model performed better? In other words, did the model that included (`Review Scores Rating` and `Neighbourhood `) or (`Review Scores Rating`, `Neighbourhood `, and `Room Type`) perform better on the test set in the single train/test split?
#
# **Answer Here:**

# %% [markdown]
# **Q2.7 (4 Points)**: Now do a 10-Fold cross validation of the model that includes `Review Scores Rating`, `Neighbourhood `, and `Room Type`. Similar to **Q2.5**, use a `random_state = 3001` and save the RMSE for each Fold. Plot the distribution of RMSE across folds as a box plot and report the mean, median, and standard deviation of the RMSE.

# %%
# Answer Here

# %% [markdown]
# **Q2.8 (4 Points):** Compare the cross validated results of both models (**Q2.5** vs **Q2.7**). Which model perorms better? Which metric did you use to compare the two models and why? Does your conclusion match your conclusion when you compared with the single train/test split?
#
# **Answer Here:**

# %% [markdown]
# ## **Question 3 (30 Points Total):**
#
# Load the `./data/wages.csv` data set. The data record the company worker hapiness scores for various data science realted jobs. The data include the following variables for each data science related jobs:
#
#   - `Rating`: Company worker happiness score
#   - `Size`: Number of employees
#   - `Sector`: Part of the economy
#   - `avg_salary`: Average wage
#   - `job_state`: Location of work
#
# **Q3.1 (4 Points):** Load the `wages.csv` file. Do any necessary data cleaning of the provided variables; consider the distribution of the variables and look for outliers or missings values.

# %%
# Answer Here

# %% [markdown]
# **Q3.2 (6 Points):**
#
# 1. Fit a linear regression model that predicts `avg_salary` using `Sector`. Split the sample into an ~80% training set and a ~20% test set. Use a random_state of `1000` for reproducibility in your single train/test split.

# %%
# Answer Here

# %% [markdown]
# 2. Based on the model you fit, what are the **top 5 sectors** with the highest predicted wages?
#
# **Answer Here:**

# %%
# Answer Here

# %% [markdown]
# 3. What is the `RMSE` of the model on the single test set? Calculate the value in the code cell below and print it to the screen.

# %%
# Answer Here

# %% [markdown]
# 4. Perform a `10-Fold cross validation` with a `random seed of 3001`. Store the RMSE for each fold. Plot the distribution of the RMSE across folds and report the mean, median, and standard deviation of the RMSE across folds.

# %%
# Answer Here

# %% [markdown]
# **Q3.3 (8 Points)**:
#
# 1. Make a scatterplot of `avg_salary` and `Rating`. Include appropriate labels and a title. Is there an obvious visual relationship between the two variables? Based on this visualization, do you think a model predicting `avg_salary` with `Rating` will perform well?
#
# **Answer Here**:

# %%
# Answer Here

# %% [markdown]
# 2. Fit a regression model predicting `avg_salary` using `Rating` as a numeric variable. Fit and test the data using a single train/test (80/20 with random state 1000). Include an intercept in your model.

# %%
# Answer Here

# %% [markdown]
# 3. Print the coefficient and intercept of the model you fit. Do higher ratings predict higher or lower wages? Report the `RMSE` of the model on the test set.
#
# **Answer Here:**

# %%
# Answer Here

# %% [markdown]
# 4. Convert `Rating` to a one-hot encoded variable. Specifically, we want a one-hot encoded column for each rounded rating. Consider what new data type it must be represented as. Fit a linear regression model to predict `avg_salary` using the new categorical version of `Rating`. Which version has a lower `RMSE` on the test data set: the numeric or categorical version of `Rating`?
#
# **Answer Here:**

# %%
# Answer Here

# %% [markdown]
# 5. How does your fitted model change when using the numeric vs categorical rating? Explain what allows the models to be different (numeric vs categorical). Hint: Use the model coefficients to calculate the predictions for each possible rating, plot them, and describe how the model behaviors are different.
#
# **Answer Here:**

# %%
# Answer Here

# %% [markdown]
# **Q3.4 (4 Points):**
#
# 1. Create an interaction term between `Sector` and the categorical version of `Rating`. This means that your regressors in the model will be a (Sector, Rating) pair. This is a programming puzzle you'll have to think about. One optiion is pre-processing a new variable that interacts `Sector` and `Rating` and then one-hot encoding the result.

# %%
# Answer Here

# %% [markdown]
# 2. Fit a linear regression model to predict `avg_salary` using the interaction (Sector, Rating) pairs you created. How does the `RMSE` on the test set compare to the models that you fit in **Q3.2** and **Q3.3**?
#
# **Answer Here:**

# %%
# Answer Here

# %% [markdown]
# 3. Interpret the coefficients from the model; which sector-rating pairs have the highest predicted wages?

# %%
# Answer Here

# %% [markdown]
# **Q3.5 (8 Points):**
#
# 1. Cross validate each of the models from above to see if your results are the same with different train/test splits. As before, use K=10 and a random state of 3001 for your cross validation. Plot the distribution of the RMSE across folds for each model and report the mean, median, and standard deviation of the RMSE for each model.

# %%
# Cross Validate Rating as Numeric Here

# %%
# Cross Validate Rating as Categorical Here

# %%
# Cross Validate Sector x Rating Interation Here

# %% [markdown]
# 2. From the results above, which model design performs the best? Which metric did you use to make that decision and why? Did your conclusions match with the results you had for a single train/test split?
#
# **Answer Here:**

# %% [markdown]
# ## **Question 4 (30 Points):**
#
# I have created a synthetic data set that you can find on GitHub in the assignments folder title `./data/Assignment3-MysteryData.csv`. This data set has three variables: `x`, `y`, `z`, all of which are numeric. `z` (target) is a function of `x` and `y` (features). This question is open ended and will hopefully give you a chance to work through feature expansion in a less directed manner, allowing you to consider different features you could include in the model.
#
# **Your goal for this question is to estimate the underlying data generating function for z using linear regression.** You do not need to recover the exact true function, but your model should capture the key relationships that are present in the underlying data generation process. So that the possibilities aren't too overwhelming, the underlying data generation process only uses feature expansions that we have discussed in class. Here are some pointers that you should use to get started and receive full credit for this question:
#
# 1. Visualize the relationships between the target (`z`) and the input features (`x`, `y`).
# 2. Consider model(s) that only use the raw input features (`x`, `y`)
# 3. Consider model(s) with additional feature expansions or relationships. View the Feature Expansion notebook for inspiration.
# 4. Use cross validation on these models to test for overfitting. Compare models using RMSE.
# 5. After going through this process select your best model and report.
#     - Report your final selected model, including the full formula with estimated coefficients
#     - Briefly justify why you selected it based on your cross-validation results.

# %%
# Answer With Code Here

# %% [markdown]
# **Discuss your final model and choices here:**
